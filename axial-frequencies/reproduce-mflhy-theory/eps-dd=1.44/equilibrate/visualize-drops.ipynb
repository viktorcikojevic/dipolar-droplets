# %% [markdown]
# From the "Supersolid symmetry breaking from compressional oscillations in a dipolar quantum gas" paper (link here [https://arxiv.org/abs/1906.02791](https://arxiv.org/abs/1906.02791)), the authors say:
#
# "The equilibrium density configuration is found by fixing the equation parameters to the values available in the experiments, and then evolving the eGPE in imaginary time. We consider $\mathrm{N}=35000$ atoms of ${ }^{162} \mathrm{Dy}$, for which $a_{d d}=130 a_0\left(a_0\right.$ is the Bohr radius). The trapping frequencies are $\omega_{x, y, z}=2 \pi(18.5,53,81) \mathrm{Hz}$, and $a_s$ is changed to tune the value of $\epsilon_{d d}$."

# %% [markdown]
# # import modules

# %%
import matplotlib.pyplot as plt

# Import dependencies
import numpy as np
import sys
sys.path.append('../../../../3D-egpe-code/egpe')
from egpe import eGPE

# %%
# Create empty eGPE object
gp = eGPE()

# %%
# Load small-box-large-dx-3 data
gp.load("small-box-large-dx-3/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), np.average(gp.den, axis=(1, 2))
# Plot the density slice
plt.plot(x, den_x/np.max(den_x), label="small-box-large-dx-3",  ls='-', marker='o', ms=3)


# Load large-box-large-dx-3 data
gp.load("large-box-large-dx-3/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), np.average(gp.den, axis=(1, 2))
# Plot the density slice
plt.plot(x, den_x/np.max(den_x), label="large-box-large-dx-3",  ls='-', marker='o', ms=3)

# put legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 10
#       6 plt.plot(x, den_x/np.max(den_x), label="small-box-large-dx-3",  ls='-', marker='o', ms=3)
#       9 # Load large-box-large-dx-3 data
# ---> 10 gp.load("large-box-large-dx-3/1-equilibrate-output/gp.pickle")
#      11 # Get the density and coordinate slices
#      12 x, den_x = gp.coordinate_slice(axis="x"), np.average(gp.den, axis=(1, 2))
#
# File /media/viktor/T7/dipolar-droplets/axial-frequencies/reproduce-mflhy-theory/eps-dd=1.44/equilibrate/../../../../3D-egpe-code/egpe/egpe.py:230, in eGPE.load(self, filename)
#     226 def load(self, filename):
#     227     """
#     228     Loads the egpe object from a file.
#     229     """
# --> 230     with open(filename, 'rb') as f:
#     231         egpe = pickle.load(f)
#     232     self.__dict__.update(egpe.__dict__)
#
# ...

# %%
# Load small-box-large-dx-3 data
gp.load("small-box-large-dx-3/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="y"), np.average(gp.den, axis=(0, 2))
# Plot the density slice
plt.plot(x, den_x/np.max(den_x), label="small-box-large-dx-3",  ls='-', marker='o', ms=3)


# Load large-box-large-dx-3 data
gp.load("large-box-large-dx-3/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="y"), np.average(gp.den, axis=(0, 2))
# Plot the density slice
plt.plot(x, den_x/np.max(den_x), label="large-box-large-dx-3",  ls='-', marker='o', ms=3)

# put legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
# Load small-box-large-dx-3 data
gp.load("small-box-large-dx-3/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="z"), np.average(gp.den, axis=(0, 1))
# Plot the density slice
plt.plot(x, den_x/np.max(den_x), label="small-box-large-dx-3",  ls='-', marker='o', ms=3)


# Load large-box-large-dx-3 data
gp.load("large-box-large-dx-3/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="z"), np.average(gp.den, axis=(0, 1))
# Plot the density slice
plt.plot(x, den_x/np.max(den_x), label="large-box-large-dx-3",  ls='-', marker='o', ms=3)

# put legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
