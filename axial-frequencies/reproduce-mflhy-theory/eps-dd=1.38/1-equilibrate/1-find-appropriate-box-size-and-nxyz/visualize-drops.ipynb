# %% [markdown]
# From the "Supersolid symmetry breaking from compressional oscillations in a dipolar quantum gas" paper (link here [https://arxiv.org/abs/1906.02791](https://arxiv.org/abs/1906.02791)), the authors say:
#
# "The equilibrium density configuration is found by fixing the equation parameters to the values available in the experiments, and then evolving the eGPE in imaginary time. We consider $\mathrm{N}=35000$ atoms of ${ }^{162} \mathrm{Dy}$, for which $a_{d d}=130 a_0\left(a_0\right.$ is the Bohr radius). The trapping frequencies are $\omega_{x, y, z}=2 \pi(18.5,53,81) \mathrm{Hz}$, and $a_s$ is changed to tune the value of $\epsilon_{d d}$."

# %% [markdown]
# # import modules

# %%
import matplotlib.pyplot as plt

# Import dependencies
import numpy as np
import sys
sys.path.append('../../../../../3D-egpe-code/egpe')
from egpe import eGPE

# %%
# Create empty eGPE object
gp = eGPE()

# %%
# Load large-box-large-dx data
gp.load("large-box-large-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), gp.density_slice(axis="x")
# Plot the density slice
plt.plot(x, den_x, label="large-box-large-dx",  ls='-', marker='o', ms=3)

# Load small-box-large-dx data
gp.load("small-box-large-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), gp.density_slice(axis="x")
# Plot the density slice
plt.plot(x, den_x, label="small-box-large-dx",  ls='-', marker='o', ms=3)

# Load small-box-small-dx data
gp.load("small-box-small-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), gp.density_slice(axis="x")
# Plot the density slice
plt.plot(x, den_x, label="small-box-small-dx",  ls='-', marker='o', ms=3)

# Load small-box-small-dx-2 data
gp.load("small-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), gp.density_slice(axis="x")
# Plot the density slice
plt.plot(x, den_x, label="small-box-small-dx-2",  ls='-', marker='', ms=3)

# Load large-box-small-dx-2
gp.load("large-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), gp.density_slice(axis="x")
# Plot the density slice
plt.plot(x, den_x, label="large-box-small-dx-2",  ls='', marker='D', ms=3)


plt.xlim(-500, 500)

# put legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
# Load small-box-small-dx-2 data
gp.load("small-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), gp.density_slice(axis="x")
# Plot the density slice
plt.plot(x, den_x, label="small-box-small-dx-2",  ls='-', marker='', ms=3)

# Load large-box-small-dx-2
gp.load("large-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
x, den_x = gp.coordinate_slice(axis="x"), gp.density_slice(axis="x")
# Plot the density slice
plt.plot(x, den_x, label="large-box-small-dx-2",  ls='', marker='D', ms=3)

plt.xlim(-1000, 1000)
# put legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
# Load large-box-large-dx data
gp.load("large-box-large-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
y, den_y = gp.coordinate_slice(axis="y"), gp.density_slice(axis="y")
# Plot the density slice
plt.plot(y, den_y, label="large-box-large-dx",  ls='-', marker='o', ms=3)

# Load small-box-large-dx data
gp.load("small-box-large-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
y, den_y = gp.coordinate_slice(axis="y"), gp.density_slice(axis="y")
# Plot the density slice
plt.plot(y, den_y, label="small-box-large-dx",  ls='-', marker='o', ms=3)

# Load small-box-small-dx data
gp.load("small-box-small-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
y, den_y = gp.coordinate_slice(axis="y"), gp.density_slice(axis="y")
# Plot the density slice
plt.plot(y, den_y, label="small-box-small-dx",  ls='-', marker='o', ms=3)

# Load small-box-small-dx-2 data
gp.load("small-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
y, den_y = gp.coordinate_slice(axis="y"), gp.density_slice(axis="y")
# Plot the density slice
plt.plot(y, den_y, label="small-box-small-dx-2",  ls='-', marker='o', ms=3)

# Load large-box-small-dx-2
gp.load("large-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
y, den_y = gp.coordinate_slice(axis="y"), gp.density_slice(axis="y")
# Plot the density slice
plt.plot(y, den_y, label="large-box-small-dx-2",  ls='', marker='D', ms=3)

plt.xlim(-500, 500)

plt.legend()

# %%
# Load small-box-small-dx-2 data
gp.load("small-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
y, den_y = gp.coordinate_slice(axis="y"), gp.density_slice(axis="y")
# Plot the density slice
plt.plot(y, den_y, label="small-box-small-dx-2",  ls='-', marker='', ms=3)

# Load large-box-small-dx-2
gp.load("large-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
y, den_y = gp.coordinate_slice(axis="y"), gp.density_slice(axis="y")
# Plot the density slice
plt.plot(y, den_y, label="large-box-small-dx-2",  ls='', marker='D', ms=3)

plt.xlim(-200, 200)
# put legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

# %%
# Load large-box-large-dx data
gp.load("large-box-large-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
z, den_z = gp.coordinate_slice(axis="z"), gp.density_slice(axis="z")
# Plot the density slice
plt.plot(z, den_z, label="large-box-large-dx",  ls='-', marker='o', ms=3)

# Load small-box-large-dx data
gp.load("small-box-large-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
z, den_z = gp.coordinate_slice(axis="z"), gp.density_slice(axis="z")
# Plot the density slice
plt.plot(z, den_z, label="small-box-large-dx",  ls='-', marker='o', ms=3)

# Load small-box-small-dx data
gp.load("small-box-small-dx/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
z, den_z = gp.coordinate_slice(axis="z"), gp.density_slice(axis="z")
# Plot the density slice
plt.plot(z, den_z, label="small-box-small-dx",  ls='-', marker='o', ms=3)

# Load small-box-small-dx-2 data
gp.load("small-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
z, den_z = gp.coordinate_slice(axis="z"), gp.density_slice(axis="z")
# Plot the density slice
plt.plot(z, den_z, label="small-box-small-dx-2",  ls='-', marker='o', ms=3)

# Load large-box-small-dx-2
gp.load("large-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
z, den_z = gp.coordinate_slice(axis="z"), gp.density_slice(axis="z")
# Plot the density slice
plt.plot(z, den_z, label="large-box-small-dx-2",  ls='', marker='D', ms=3)

plt.xlim(-500, 500)

plt.legend()

# %%
# Load small-box-small-dx-2 data
gp.load("small-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
z, den_z = gp.coordinate_slice(axis="z"), gp.density_slice(axis="z")
# Plot the density slice
plt.plot(z, den_z, label="small-box-small-dx-2",  ls='-', marker='', ms=3)

# Load large-box-small-dx-2
gp.load("large-box-small-dx-2/1-equilibrate-output/gp.pickle")
# Get the density and coordinate slices
z, den_z = gp.coordinate_slice(axis="z"), gp.density_slice(axis="z")
# Plot the density slice
plt.plot(z, den_z, label="large-box-small-dx-2",  ls='', marker='D', ms=3)

plt.xlim(-200, 200)
# put legend outside of plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
